# %%
# !git clone https://github.com/RenataGaripova/CV-Group-Project---Road-Object-Detection-
# Out:
# Cloning into 'CV-Group-Project---Road-Object-Detection-'...
# remote: Enumerating objects: 4, done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (4/4), 96.75 MiB | 50.73 MiB/s, done.

# %%
# !ls CV-Group-Project---Road-Object-Detection-
# Out:
# cardetection.zip  final_project.ipynb

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/CV-Group-Project---Road-Object-Detection/car/data.yaml",
    epochs=30,
    imgsz=512,
    batch=16,
    optimizer="Adam",
    lr0=1e-4
)
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.predict(
    source="/content/CV-Group-Project---Road-Object-Detection/car/test/images",
    save=True
)
# Out:
# image 1/638 /content/CV-Group-Project---Road-Object-Detection/car/test/images/000003_jpg.rf.8511b9c219dbf9799a6d58900b15917d.jpg: 512x512 1 Speed Limit 30, 8.4ms
# image 2/638 /content/CV-Group-Project---Road-Object-Detection/car/test/images/000006_jpg.rf.89610ec419ccfab22f8314026b90ee26.jpg: 512x512 1 Speed Limit 30, 6.1ms
# image 3/638 /content/CV-Group-Project---Road-Object-Detection/car/test/images/00000_00000_00003_png.rf.d18afc3c9625ffb1974029d3e3762aee.jpg: 512x512 1 Speed Limit 20, 6.2ms
# image 4/638 /content/CV-Group-Project---Road-Object-Detection/car/test/images/00000_00000_00005_png.rf.ab60a274676963d378f5014e89d9e2b1.jpg: 512x512 1 Speed Limit 20, 5.9ms
# image 5/638 /content/CV-Group-Project---Road-Object-Detection/car/test/images/00000_00000_00006_png.rf.9d1ea68507aff6973a1dbcdc6f4422a8.jpg: 512x512 1 Speed Limit 20, 6.6ms
# ...
